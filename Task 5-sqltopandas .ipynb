# %%
# !pip install pandas pyodbc sqlalchemy
# Out:
# Requirement already satisfied: pandas in c:\users\nandha\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: pyodbc in c:\users\nandha\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: sqlalchemy in c:\users\nandha\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nandha\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nandha\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nandha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nandha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\nandha\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nandha\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\nandha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import pyodbc

print("Pandas version:", pd.__version__)
print("PyODBC installed successfully")
# Out:
# Pandas version: 2.3.3
# PyODBC installed successfully

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'ODBC Driver 18 for SQL Server', 'ODBC Driver 17 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
import pyodbc

server = "localhost"
database = "churnDB"

connection_string = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=" + server + ";"
    "DATABASE=" + database + ";"
    "Trusted_Connection=yes;"
)

conn = pyodbc.connect(connection_string, timeout=10)

print("Connected to SQL Server successfully!")
print("Database:", database)
# Out:
# Connected to SQL Server successfully!
# Database: churnDB

# %%
import pandas as pd
query="SELECT*FROM dbo.vw_ChurnData"
df=pd.read_sql(query,conn)
print("Data loaded successfully!")
print("Rows and columns:",df.shape)
# Out:
# C:\Users\nandha\AppData\Local\Temp\ipykernel_16916\332336603.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
# Data loaded successfully!
# Rows and columns: (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female          False     True       False       1
# 1  5575-GNVDE    Male          False    False       False      34
# 2  3668-QPYBK    Male          False    False       False       2
# 3  7795-CFOCW    Male          False    False       False      45
# 4  9237-HQITU  Female          False    False       False       2
#
#    PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0         False          None             DSL          False  ...
# 1          True         False             DSL           True  ...
# 2          True         False             DSL           True  ...
# 3         False          None             DSL           True  ...
# 4          True         False     Fiber optic          False  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0            False       False       False           False  Month-to-month
# 1             True       False       False           False        One year
# 2            False       False       False           False  Month-to-month
# 3             True        True       False           False        One year
# 4            False       False       False           False  Month-to-month
#
#   PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0             True           Electronic check      29.850000         29.85
# 1            False               Mailed check      56.950001       1889.50
# 2             True               Mailed check      53.849998        108.15
# 3            False  Bank transfer (automatic)      42.299999       1840.75
# 4             True           Electronic check      70.699997        151.65
#
#    Churn
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   bool
#  3   Partner           7043 non-null   bool
#  4   Dependents        7043 non-null   bool
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   bool
#  7   MultipleLines     6361 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    5517 non-null   object
#  10  OnlineBackup      5517 non-null   object
#  11  DeviceProtection  5517 non-null   object
#  12  TechSupport       5517 non-null   object
#  13  StreamingTV       5517 non-null   object
#  14  StreamingMovies   5517 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   bool
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   bool
# dtypes: bool(6), float64(2), int64(1), object(12)
# memory usage: 866.7+ KB
